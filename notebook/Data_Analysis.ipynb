# %%
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
dataset = pd.read_csv('/content/gdrive/MyDrive/dataset.csv', index_col=False)

# %%
dataset.head()
# Out:
#       bearer_id            start  start_ms              end  end_ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    dur._(ms)          imsi  msisdn/number          imei  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       last_location_name  ...  total_ul_(bytes)  total_dl_(bytes)  \
# 0  9.16456699548519E+015  ...         36.749741        308.879636
# 1                L77566A  ...         53.800391        653.384965
# ...

# %%
dataset.shape
# Out:
# (150001, 53)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   bearer_id                         150001 non-null  float64
#  1   start                             150001 non-null  object
#  2   start_ms                          150001 non-null  float64
#  3   end                               150001 non-null  object
#  4   end_ms                            150001 non-null  float64
#  5   dur._(ms)                         150001 non-null  float64
#  6   imsi                              150001 non-null  float64
#  7   msisdn/number                     150001 non-null  float64
#  8   imei                              150001 non-null  float64
#  9   last_location_name                150001 non-null  object
#  10  avg_rtt_dl_(ms)                   150001 non-null  float64
# ...

# %%
dataset.isnull().sum()
# Out:
# bearer_id                           0
# start                               0
# start_ms                            0
# end                                 0
# end_ms                              0
# dur._(ms)                           0
# imsi                                0
# msisdn/number                       0
# imei                                0
# last_location_name                  0
# avg_rtt_dl_(ms)                     0
# avg_rtt_ul_(ms)                     0
# avg_bearer_tp_dl_(kbps)             0
# avg_bearer_tp_ul_(kbps)             0
# dl_tp_<_50_kbps_(%)                 0
# 50_kbps_<_dl_tp_<_250_kbps_(%)      0
# 250_kbps_<_dl_tp_<_1_mbps_(%)       0
# dl_tp_>_1_mbps_(%)                  0
# ul_tp_<_10_kbps_(%)                 0
# 10_kbps_<_ul_tp_<_50_kbps_(%)       0
# 50_kbps_<_ul_tp_<_300_kbps_(%)      0
# ul_tp_>_300_kbps_(%)                0
# activity_duration_dl_(ms)           0
# activity_duration_ul_(ms)           0
# dur._(ms).1                         0
# ...

# %%
#Univarite analysis

# %%
#Dur (ms)
dataset[['dur._(ms)']].describe()
# Out:
#           dur._(ms)
# count  1.500010e+05
# mean   1.046086e+05
# std    8.103735e+04
# min    7.142000e+03
# 25%    5.744200e+04
# 50%    8.639900e+04
# 75%    1.324300e+05
# max    1.859336e+06

# %%
# Plotting histogram with plt.hist
plt.figure(figsize=(12, 7))
plt.hist(dataset['dur._(ms)'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Distribution of dur._(ms)')
plt.xlabel('Duration (ms)')
plt.ylabel('Frequency')
plt.show()

# %%
#Youtube Data Volume

dataset[['Youtube Data Volume (Bytes)']].describe()
# Out:
#        Youtube Data Volume (Bytes)
# count                150001.000000
# mean                     22.643483
# std                       9.246800
# min                       0.078903
# 25%                      15.998463
# 50%                      22.661770
# 75%                      29.292604
# max                      45.190078

# %%
# Plotting histogram with plt.hist
plt.figure(figsize=(12, 7))
plt.hist(dataset['Youtube Data Volume (Bytes)'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Distribution of Youtube Data Volume (Bytes)')
plt.xlabel('Youtube Data Volume (Bytes)')
plt.ylabel('Frequency')
plt.show()

# %%
dataset[['Netflix Data Volume (Bytes)']].describe()
# Out:
#        Netflix Data Volume (Bytes)
# count                150001.000000
# mean                     22.628607
# std                       9.260820
# min                       0.098432
# 25%                      15.979455
# 50%                      22.635545
# 75%                      29.290445
# max                      45.198153

# %%
# Plotting histogram with plt.hist
plt.figure(figsize=(12, 7))
plt.hist(dataset['Netflix Data Volume (Bytes)'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Distribution of Netflix Data Volume (Bytes)')
plt.xlabel('Netflix Data Volume (Bytes)')
plt.ylabel('Frequency')
plt.show()

# %%
dataset[['Google Data Volume (Bytes)']].describe()
# Out:
#        Google Data Volume (Bytes)
# count               150001.000000
# mean                     7.807295
# std                      3.516420
# min                      0.040330
# 25%                      4.943599
# 50%                      7.812835
# 75%                     10.682796
# max                     15.528782

# %%
"""numerical_data = dataset.select_dtypes(include=['float64', 'int64'])
sns.pairplot(numerical_data)
plt.suptitle('Scatter Plot Matrix of Numerical Variables', y=1.02)
plt.show()"""
# Out:
# "numerical_data = dataset.select_dtypes(include=['float64', 'int64'])\nsns.pairplot(numerical_data)\nplt.suptitle('Scatter Plot Matrix of Numerical Variables', y=1.02)\nplt.show()"

# %%
"""numerical_data = dataset.select_dtypes(include=['float64', 'int64'])
sns.pairplot(numerical_data, diag_kind='kde')
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()"""
# Out:
# "numerical_data = dataset.select_dtypes(include=['float64', 'int64'])\nsns.pairplot(numerical_data, diag_kind='kde') \nplt.suptitle('Pair Plot of Numerical Variables', y=1.02)\nplt.show()"

# %%
df_corr = dataset[[
    'Social Media Data Volume (Bytes)', 'Google Data Volume (Bytes)', 'Email Data Volume (Bytes)',
    'Youtube Data Volume (Bytes)', 'Netflix Data Volume (Bytes)', 'Gaming Data Volume (Bytes)',
    'Other Data Volume (Bytes)']
].corr()
df_corr
# Out:
#                                   Social Media Data Volume (Bytes)  \
# Social Media Data Volume (Bytes)                          1.000000
# Google Data Volume (Bytes)                               -0.001708
# Email Data Volume (Bytes)                                 0.004032
# Youtube Data Volume (Bytes)                               0.000548
# Netflix Data Volume (Bytes)                               0.001013
# Gaming Data Volume (Bytes)                                0.001082
# Other Data Volume (Bytes)                                 0.006065
#
#                                   Google Data Volume (Bytes)  \
# Social Media Data Volume (Bytes)                   -0.001708
# Google Data Volume (Bytes)                          1.000000
# Email Data Volume (Bytes)                          -0.000412
# Youtube Data Volume (Bytes)                         0.002277
# Netflix Data Volume (Bytes)                        -0.001902
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation of Applications Data Volume")
plt.show()

# %%
# User Overview Data Analysis

# %% [markdown]
# ### Top 10 handset types

# %%
#Top 10 Handset types
dataset['handset_type'].value_counts().head(10)
# Out:
# handset_type
# Huawei B528S-23A                19792
# Apple iPhone 6S (A1688)          9452
# Apple iPhone 6 (A1586)           9059
# undefined                        9018
# Apple iPhone 7 (A1778)           6361
# Apple iPhone Se (A1723)          5211
# Apple iPhone 8 (A1905)           5028
# Apple iPhone Xr (A2105)          4588
# Samsung Galaxy S8 (Sm-G950F)     4539
# Apple iPhone X (A1901)           3825
# Name: count, dtype: int64

# %%
top_10 = dataset["handset_type"].value_counts()[:10]
plt.figure(figsize=(10,5))
top_10.plot(kind="bar",title="top 10 handset types")
plt.show()

# %%
dataset.columns
# Out:
# Index(['bearer_id', 'start', 'start_ms', 'end', 'end_ms', 'dur._(ms)', 'imsi',
#        'msisdn/number', 'imei', 'last_location_name', 'avg_rtt_dl_(ms)',
#        'avg_rtt_ul_(ms)', 'avg_bearer_tp_dl_(kbps)', 'avg_bearer_tp_ul_(kbps)',
#        'dl_tp_<_50_kbps_(%)', '50_kbps_<_dl_tp_<_250_kbps_(%)',
#        '250_kbps_<_dl_tp_<_1_mbps_(%)', 'dl_tp_>_1_mbps_(%)',
#        'ul_tp_<_10_kbps_(%)', '10_kbps_<_ul_tp_<_50_kbps_(%)',
#        '50_kbps_<_ul_tp_<_300_kbps_(%)', 'ul_tp_>_300_kbps_(%)',
#        'activity_duration_dl_(ms)', 'activity_duration_ul_(ms)', 'dur._(ms).1',
#        'handset_manufacturer', 'handset_type', 'nb_of_sec_with_vol_dl_<_6250b',
#        'nb_of_sec_with_vol_ul_<_1250b', 'social_media_dl_(bytes)',
#        'social_media_ul_(bytes)', 'google_dl_(bytes)', 'google_ul_(bytes)',
#        'email_dl_(bytes)', 'email_ul_(bytes)', 'youtube_dl_(bytes)',
#        'youtube_ul_(bytes)', 'netflix_dl_(bytes)', 'netflix_ul_(bytes)',
# ...

# %%
#Handset Manufacturers
Top_3_Manufacturer = dataset[['handset_manufacturer']].value_counts().head(3)
Top_3_Manufacturer
# Out:
# handset_manufacturer
# Apple                   59827
# Samsung                 40978
# Huawei                  34529
# Name: count, dtype: int64

# %%
top_3_handset_manufacturer = dataset["handset_manufacturer"].value_counts()[:3]
plt.figure(figsize=(10,5))
top_3_handset_manufacturer.plot(kind="bar",title="top 3 handset manufacturers")
plt.show()

# %%
Top_3_manf = dataset['handset_manufacturer'].value_counts().head(3)
Top_3_manf = dataset[dataset["handset_manufacturer"].isin(Top_3_manf.index.tolist())]
top_handsets = Top_3_manf['handset_type'].groupby(dataset['handset_manufacturer']).apply(lambda x: x.value_counts().head(5))
top_handsets
# Out:
# handset_manufacturer
# Apple                 Apple iPhone 6S (A1688)            9452
#                       Apple iPhone 6 (A1586)             9059
#                       Apple iPhone 7 (A1778)             6361
#                       Apple iPhone Se (A1723)            5211
#                       Apple iPhone 8 (A1905)             5028
# Huawei                Huawei B528S-23A                  19792
#                       Huawei E5180                       2084
#                       Huawei P20 Lite Huawei Nova 3E     2032
#                       Huawei P20                         1482
#                       Huawei Y6 2018                     1002
# Samsung               Samsung Galaxy S8 (Sm-G950F)       4539
#                       Samsung Galaxy A5 Sm-A520F         3737
#                       Samsung Galaxy J5 (Sm-J530)        3705
#                       Samsung Galaxy J3 (Sm-J330)        3493
#                       Samsung Galaxy S7 (Sm-G930X)       3211
# ...

# %%
handsets_per_manufacturers=dataset[dataset["handset_manufacturer"].str.contains("Apple|Samsung|Huawei") ][["handset_manufacturer","handset_type"]]
plt.figure(figsize=(10,5))
top_five_apple_handset_type=handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Apple')["handset_type"].value_counts()[:5]
handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Apple')["handset_type"].value_counts()[:5].plot(kind='bar', title="Top 5 handset types by Apple")
plt.show()

# %%
plt.figure(figsize=(10,5))
top_five_samsung_handset_type=handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Apple')["handset_type"].value_counts()[:5]
handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Apple')["handset_type"].value_counts()[:5].plot(kind='bar', title="Top 5 handset types by Apple")
plt.show()

# %%
plt.figure(figsize=(10,5))
top_five_huawei_handset_type=handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Huawei')["handset_type"].value_counts()[:5]
handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Huawei')["handset_type"].value_counts()[:5].plot(kind='bar', title="Top 5 handset types by Huawei")
plt.show()

# %%
plt.figure(figsize=(10,5))
top_five_huawei_handset_type=handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Samsung')["handset_type"].value_counts()[:5]
handsets_per_manufacturers.groupby(["handset_manufacturer"]).get_group('Samsung')["handset_type"].value_counts()[:5].plot(kind='bar', title="Top 5 handset types by Samsung")
plt.show()

# %%
print(dataset.columns)
# Out:
# Index(['bearer_id', 'start', 'start_ms', 'end', 'end_ms', 'dur._(ms)', 'imsi',
#        'msisdn/number', 'imei', 'last_location_name', 'avg_rtt_dl_(ms)',
#        'avg_rtt_ul_(ms)', 'avg_bearer_tp_dl_(kbps)', 'avg_bearer_tp_ul_(kbps)',
#        'dl_tp_<_50_kbps_(%)', '50_kbps_<_dl_tp_<_250_kbps_(%)',
#        '250_kbps_<_dl_tp_<_1_mbps_(%)', 'dl_tp_>_1_mbps_(%)',
#        'ul_tp_<_10_kbps_(%)', '10_kbps_<_ul_tp_<_50_kbps_(%)',
#        '50_kbps_<_ul_tp_<_300_kbps_(%)', 'ul_tp_>_300_kbps_(%)',
#        'activity_duration_dl_(ms)', 'activity_duration_ul_(ms)', 'dur._(ms).1',
#        'handset_manufacturer', 'handset_type', 'nb_of_sec_with_vol_dl_<_6250b',
#        'nb_of_sec_with_vol_ul_<_1250b', 'social_media_dl_(bytes)',
#        'social_media_ul_(bytes)', 'google_dl_(bytes)', 'google_ul_(bytes)',
#        'email_dl_(bytes)', 'email_ul_(bytes)', 'youtube_dl_(bytes)',
#        'youtube_ul_(bytes)', 'netflix_dl_(bytes)', 'netflix_ul_(bytes)',
# ...

# %%
XDR = dataset.groupby('msisdn/number')['msisdn/number'].agg('count').reset_index(name='Bearer Id').sort_values(by='Bearer Id',
        ascending=False)

XDR.rename(columns={XDR.columns[1]: 'number of xDR sessions'}, inplace=True)
XDR
# Out:
#         msisdn/number  number of xDR sessions
# 106853   4.188282e+10                    1066
# 13526    3.362632e+10                      18
# 13180    3.362578e+10                      17
# 6437     3.361489e+10                      17
# 37052    3.365973e+10                      16
# ...               ...                     ...
# 41061    3.366068e+10                       1
# 41059    3.366068e+10                       1
# 41058    3.366067e+10                       1
# 41057    3.366067e+10                       1
# 106856   8.823971e+14                       1
#
# [106857 rows x 2 columns]

# %%
Average_session_Duration_per_user = dataset.groupby('msisdn/number').agg({'dur._(ms)': 'mean'})
Average_session_Duration_per_user.rename(
        columns={'dur._(ms)': 'Average session duration (ms)'}, inplace=True)
Average_session_Duration_per_user.sort_values(by=['Average session duration (ms)'], ascending=False).head(10)
# Out:
#                Average session duration (ms)
# msisdn/number
# 3.366926e+10                       1573420.0
# 3.366172e+10                       1480875.0
# 3.360750e+10                       1474663.0
# 3.376260e+10                       1375612.0
# 3.376063e+10                       1361762.0
# 3.376167e+10                       1357643.0
# 3.375034e+10                       1321509.0
# 3.366682e+10                       1299381.0
# 3.369870e+10                       1209607.0
# 3.363050e+10                       1177517.0

# %%
dataset['total_ul_(bytes)'] = dataset['total_ul_(bytes)'].astype("int64")
dataset['total_dl_(bytes)'] = dataset['total_dl_(bytes)'].astype("int64")
dataset['Total Data Volume (Bytes)'] = dataset['Total Data Volume (Bytes)'].astype("int64")
Total = dataset.groupby('msisdn/number')[[ 'total_ul_(bytes)', 'total_dl_(bytes)', 'Total Data Volume (Bytes)']].sum()
Total.nlargest(1000, 'Total Data Volume (Bytes)')
# Out:
#                total_ul_(bytes)  total_dl_(bytes)  Total Data Volume (Bytes)
# msisdn/number
# 4.188282e+10              43819            486853                     531211
# 3.361489e+10                679              8148                       8836
# 3.376054e+10                695              7802                       8508
# 3.362578e+10                718              7761                       8491
# 3.362632e+10                659              7292                       7963
# ...                         ...               ...                        ...
# 3.378369e+10                275              2270                       2548
# 3.369886e+10                171              2375                       2547
# 3.376161e+10                149              2395                       2546
# 3.365993e+10                202              2340                       2544
# 3.366324e+10                128              2414                       2544
#
# [1000 rows x 3 columns]

# %%
For_each_application = dataset.groupby('msisdn/number')[['Social Media Data Volume (Bytes)', 'Google Data Volume (Bytes)',
    'Email Data Volume (Bytes)', 'Youtube Data Volume (Bytes)', 'Netflix Data Volume (Bytes)',
    'Gaming Data Volume (Bytes)', 'Other Data Volume (Bytes)', 'Total Data Volume (Bytes)']].sum()
For_each_application.nlargest(1000, 'Total Data Volume (Bytes)')
# Out:
#                Social Media Data Volume (Bytes)  Google Data Volume (Bytes)  \
# msisdn/number
# 4.188282e+10                        1973.817362                 8248.576911
# 3.361489e+10                          28.294544                  127.973787
# 3.376054e+10                          39.783189                  123.223099
# 3.362578e+10                          27.135500                  142.307915
# 3.362632e+10                          43.374779                  152.191852
# ...                                         ...                         ...
# 3.378369e+10                          11.901774                   49.233332
# 3.369886e+10                          12.410212                   34.846518
# 3.376161e+10                          10.299259                   33.022103
# 3.365993e+10                           8.622557                   19.822657
# 3.366324e+10                           5.338766                   20.881605
#
# ...

# %%
#Variable Transformation

# %%
decile = dataset.copy().drop_duplicates(subset=['dur._(ms)'])  # Drop rows with duplicate durations
decile['Decile'] = pd.qcut(decile['dur._(ms)'], 10, labels=False)

# %%
decile = dataset.copy()
decile['Decile'] = pd.qcut(decile['dur._(ms)'], 10, labels=False, duplicates='drop')  # Drop duplicates

# %%
decile =  decile.groupby(['Decile']).agg({'dur._(ms)': "sum","Total Data Volume (Bytes)": "sum"}).sort_values(by='dur._(ms)',ascending=False)
decile
# Out:
#            dur._(ms)  Total Data Volume (Bytes)
# Decile
# 8       4.145847e+09                    7452110
# 3       2.779989e+09                   16125509
# 7       2.467169e+09                    7451214
# 6       1.985004e+09                    7409407
# 5       1.536359e+09                    7429286
# 4       1.077622e+09                    6082915
# 2       8.649512e+08                    7470677
# 1       5.397770e+08                    7437382
# 0       2.946717e+08                    7431748

# %%
# Principal component Analysis

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

Dataset_float = dataset.select_dtypes(include=[float])
dataset_int = dataset.select_dtypes(include=[int])

Num_array = Dataset_float.columns.to_list() + dataset_int.columns.to_list()

# Standardizing Features
features = Num_array
x = dataset.loc[:, features].values
x = StandardScaler().fit_transform(x)
explained_variances = []
component_numbers = [10, 20, 30, 40]

for number in component_numbers:
    pca = PCA(n_components=number)
    pca.fit(x)
    explained_variances.append(pca.explained_variance_ratio_.sum())

# Plot cumulative explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(component_numbers, explained_variances, marker='o', linestyle='--')
plt.title('Cumulative Explained Variance Ratio vs. Number of Principal Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
# User Engagement Data Analysis

# %%
user_engagement = dataset[['misisdn/number', 'bearer_id', 'dur._(ms)', 'Total Data Volume (Bytes)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-711ad5d4034c> in <cell line: 1>()
# ----> 1 user_engagement = dataset[['misisdn/number', 'bearer_id', 'dur._(ms)', 'Total Data Volume (Bytes)']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3897             if is_iterator(key):
#    3898                 key = list(key)
# -> 3899             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3900
#    3901         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6113             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6114
# -> 6115         self._raise_if_missing(keyarr, indexer, axis_name)
#    6116
#    6117         keyarr = self.take(indexer)
#
# ...

# %%
user_engagement = user_engagement.groupby(
    'msisdn/number').agg({'bearer_id': 'count', 'dur._(ms)': 'sum', 'Total Data Volume (Bytes)': 'sum'})
#Renaming columns:
user_engagement = user_engagement.rename(
    columns={'Bearer Id': 'xDR Sessions'})
user_engagement.head()

# %%
user_engagement.nlargest(10, 'xDR Sessions')

# %%
user_engagement.nlargest(10, 'dur._(ms)')

# %%
user_engagement.nlargest(10, 'Total Data Volume (Bytes)')

# %%
class_level = Util(user_engagement)

# %%
class_level.getOverview(['xDR Sessions', 'dur._(ms)', 'Total Data Volume (Bytes)'])

# %%
class_level.replace_outliers_with_fences(['xDR Sessions', 'Dur (ms)', 'Total Data Volume (Bytes)'])

# %%
class_level.getOverview(['xDR Sessions', 'dur._(ms)', 'Total Data Volume (Bytes)'])

# %%
# K-means clustering

# %%
scaler_instance = StandardScaler()
scaled_data = scaler_instance.fit_transform(user_engagement)
scaled_data

# %%
normalized_data = normalize(scaled_data)
normalized_data

# %%
kmeans = KMeans(n_clusters=3, random_state=1).fit(normalized_data)
kmeans.labels_

# %%
user_engagement.insert(0, 'cluster', kmeans.labels_)
user_engagement

# %%
user_engagement['cluster'].value_counts()

# %%
Index(['bearer_id', 'start', 'start_ms', 'end', 'end_ms', 'dur._(ms)', 'imsi',
       'msisdn/number', 'imei', 'last_location_name', 'avg_rtt_dl_(ms)',
       'avg_rtt_ul_(ms)', 'avg_bearer_tp_dl_(kbps)', 'avg_bearer_tp_ul_(kbps)',
       'dl_tp_<_50_kbps_(%)', '50_kbps_<_dl_tp_<_250_kbps_(%)',
       '250_kbps_<_dl_tp_<_1_mbps_(%)', 'dl_tp_>_1_mbps_(%)',
       'ul_tp_<_10_kbps_(%)', '10_kbps_<_ul_tp_<_50_kbps_(%)',
       '50_kbps_<_ul_tp_<_300_kbps_(%)', 'ul_tp_>_300_kbps_(%)',
       'activity_duration_dl_(ms)', 'activity_duration_ul_(ms)', 'dur._(ms).1',
       'handset_manufacturer', 'handset_type', 'nb_of_sec_with_vol_dl_<_6250b',
       'nb_of_sec_with_vol_ul_<_1250b', 'social_media_dl_(bytes)',
       'social_media_ul_(bytes)', 'google_dl_(bytes)', 'google_ul_(bytes)',
       'email_dl_(bytes)', 'email_ul_(bytes)', 'youtube_dl_(bytes)',
       'youtube_ul_(bytes)', 'netflix_dl_(bytes)', 'netflix_ul_(bytes)',
       'gaming_dl_(bytes)', 'gaming_ul_(bytes)', 'other_dl_(bytes)',
       'other_ul_(bytes)', 'total_ul_(bytes)', 'total_dl_(bytes)',
       'Social Media Data Volume (Bytes)', 'Google Data Volume (Bytes)',
       'Email Data Volume (Bytes)', 'Youtube Data Volume (Bytes)',
       'Netflix Data Volume (Bytes)', 'Gaming Data Volume (Bytes)',
       'Other Data Volume (Bytes)', 'Total Data Volume (Bytes)'],
      dtype='object')
